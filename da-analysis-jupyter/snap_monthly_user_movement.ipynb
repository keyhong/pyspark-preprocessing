# %% [markdown]
# # Packages Loading

# %%
import os

from pyspark.sql import SparkSession
import pyspark.sql.functions as F

# %% [markdown]
# # Spark Config Setting

# %%
SPARK_JAR_DIR = os.getenv("SPARK_JAR_DIR", "/opt/spark/jars")

SPARK_STAND_ALONE_CORES = {
    "spark.cores.max": 3
}

SPARK_DRIVER_CONFIGS = {
    "spark.driver.memory": "1g"
}

SPARK_EXECUTOR_CONFIGS = {
    "spark.executor.cores": 1,
    "spark.executor.instances": 1,
    "spark.executor.memory": "1g",
}

spark = SparkSession.builder \
    .appName("etl_snapshot") \
    .master("spark://spark-master:7077") \
    .config("spark.jars", f"{SPARK_JAR_DIR}/mysql-connector-java-8.0.28.jar") \
    .config("spark.ui.port", "4040") \
    .config(map=SPARK_DRIVER_CONFIGS) \
    .config(map=SPARK_EXECUTOR_CONFIGS) \
    .config(map=SPARK_STAND_ALONE_CORES) \
    .getOrCreate()

spark.sparkContext.setJobGroup("Monthly User Movements Snapshot", "Monthly Active Users (MAU) composed of new users, returning users, and existing users", interruptOnCancel=False)

# %% [markdown]
# # RDB Connection Info

# %%
DB_CONN_INFO = {
    "user": "root",
    "password": "root",
    "url": "jdbc:mysql://mysql:3306/mysql",
    "driver": "com.mysql.cj.jdbc.Driver"
}

# %% [markdown]
# # Data Sourcing

# %% [markdown]
# ### 1. 검색 조건 일자 세팅 (Delta Load)

# %%
start_de = "1970-01-01"
end_de = "2022-07-31"

# %% [markdown]
# ### 2. 검색 조건에 부합하는 전체 데이터 셋 집합 카운트 수 산출

# %%
count_sql = f"""
    SELECT MAX(CUST_ID)
      FROM dm.dm_f_ordr
     WHERE ORDR_DE BETWEEN '{start_de}' AND '{end_de}'
"""

# 검색할 범주의 전체 행의 개수 산출 (파티션 수를 균등하게 분할하여 읽기 위한 전체 개수 탐색)
row_count_sql =  spark.read.format("jdbc") \
    .options(**DB_CONN_INFO) \
    .option("query", count_sql) \
    .load()

row_count = row_count_sql.first()[0]

# %% [markdown]
# ### 3. 여러 개의 파티션으로 균등 분할하여 데이터 Read

# %%
dbtable = f"""(
SELECT CUST_ID
     , DATE(YM01)                                                                          AS ORDR_YM_01
     , DATE_FORMAT(YM01, '%Y-%m')                                                          AS ORDR_YM
     , LAG(YM01, 1) OVER (PARTITION BY CUST_ID ORDER BY YM01)                              AS PRIOR_ORDR_YM
     , TIMESTAMPDIFF(MONTH, LAG(YM01, 1) OVER (PARTITION BY CUST_ID ORDER BY YM01), YM01)  AS ORDR_MONTH_DIFF
FROM (    
    SELECT DISTINCT CUST_ID
                  , DATE_FORMAT(ORDR_DE, '%Y-%m-01') AS YM01
      FROM dm.dm_f_ordr
     WHERE ORDR_DE BETWEEN '{start_de}' AND '{end_de}'
    ) AS user_monthly_order
) as subquery"""

sdf = spark.read.format("jdbc") \
    .options(**DB_CONN_INFO) \
    .option("numPartitions", 3) \
    .option("dbtable", dbtable) \
    .option("partitionColumn", "CUST_ID") \
    .option("lowerBound", 1) \
    .option("upperBound", row_count) \
    .load()

sdf.cache()
# Out:
# DataFrame[CUST_ID: int, ORDR_YM_01: date, ORDR_YM: string, PRIOR_ORDR_YM: string, ORDR_MONTH_DIFF: bigint]

# %%
# 파티션 개수
sdf.rdd.getNumPartitions()
# Out:
# 3

# %%
# 파티션별 (파티션 인덱스, 데이터) 개수 => 3개 파티션으로 데이터를 분할해서 읽음 (각 파티션에는 customer_id별로 모아져있음)
sdf.rdd.mapPartitionsWithIndex(lambda idx, it: [(idx, sum(1 for _ in it))]).collect()
# Out:
# [(0, 190486), (1, 187891), (2, 187164)]

# %%
# 데이터프레임 스키마 확인
sdf.printSchema()
# Out:
# root
#  |-- CUST_ID: integer (nullable = true)
#  |-- ORDR_YM_01: date (nullable = true)
#  |-- ORDR_YM: string (nullable = true)
#  |-- PRIOR_ORDR_YM: string (nullable = true)
#  |-- ORDR_MONTH_DIFF: long (nullable = true)

# %%
# Case 1 : ORDR_MONTH_DIFF => null. 그 달의 신규 회원.
new_user_sdf = sdf.filter(F.col("ORDR_MONTH_DIFF").isNull()).groupBy("ORDR_YM").agg(F.count("ORDR_YM").alias("new_user"))

# Case 2 : ORDR_MONTH_DIFF => 3 이상. 복귀 사용자
old_user_sdf = sdf.filter(F.col("ORDR_MONTH_DIFF") >= 3).groupBy("ORDR_YM").agg(F.count("ORDR_YM").alias("returning_user"))

# Case 3 : ORDR_MONTH_DIFF => 3 미만. 기존 사용자
exist_user_sdf = sdf.filter(F.col("ORDR_MONTH_DIFF") <= 2).groupBy("ORDR_YM").agg(F.count("ORDR_YM").alias("existing_user"))

# %%
new_old = new_user_sdf.join(other=old_user_sdf, on="ORDR_YM", how="full_outer")

# %%
mau_users_sdf = new_old.join(other=exist_user_sdf, on="ORDR_YM", how="full_outer")
mau_users_sdf = mau_users_sdf.na.fill(0)
mau_users_sdf = mau_users_sdf.withColumn("mau", F.col("new_user") + F.col("returning_user") + F.col("existing_user"))

# %%
mau_users_sdf.show(200)
# Out:
# +-------+--------+--------------+-------------+-----+
# |ORDR_YM|new_user|returning_user|existing_user|  mau|
# +-------+--------+--------------+-------------+-----+
# |2016-06|       1|             0|            0|    1|
# |2016-07|     268|             0|            0|  268|
# |2016-08|     423|             0|           43|  466|
# |2016-09|     435|             0|          150|  585|
# |2016-10|     512|            10|          252|  774|
# |2016-11|     488|            42|          372|  902|
# |2016-12|     280|            54|          494|  828|
# |2017-01|     498|           112|          532| 1142|
# |2017-02|     471|           138|          620| 1229|
# |2017-03|     516|           144|          746| 1406|
# |2017-04|     498|           171|          886| 1555|
# |2017-05|     463|           221|         1008| 1692|
# |2017-06|     277|           258|         1105| 1640|
# |2017-07|     981|           303|         1183| 2467|
# |2017-08|     590|           346|         1393| 2329|
# |2017-09|     592|           324|         1611| 2527|
# |2017-10|     655|           456|         1731| 2842|
# |2017-11|     543|           455|         1871| 2869|
# |2017-12|     386|           532|         2067| 2985|
# |2018-01|     552|           522|         2152| 3226|
# |2018-02|     554|           533|         2131| 3218|
# |2018-03|     589|           655|         2334| 3578|
# |2018-04|     594|           723|         2510| 3827|
# |2018-05|     519|           733|         2706| 3958|
# |2018-06|     401|           683|         2762| 3846|
# |2018-07|    1143|           868|         2919| 4930|
# |2018-08|     675|           882|         3175| 4732|
# |2018-09|     672|           844|         3366| 4882|
# |2018-10|     643|          1036|         3521| 5200|
# |2018-11|     627|           998|         3625| 5250|
# |2018-12|     417|          1100|         3874| 5391|
# |2019-01|     563|          1197|         3903| 5663|
# |2019-02|     649|          1010|         3804| 5463|
# |2019-03|     689|          1275|         4222| 6186|
# |2019-04|     625|          1235|         4267| 6127|
# |2019-05|     643|          1297|         4635| 6575|
# |2019-06|     408|          1293|         4612| 6313|
# |2019-07|    1180|          1463|         4830| 7473|
# |2019-08|     792|          1557|         5038| 7387|
# |2019-09|     717|          1522|         5228| 7467|
# |2019-10|     670|          1654|         5417| 7741|
# |2019-11|     731|          1800|         5605| 8136|
# |2019-12|     443|          1722|         5804| 7969|
# |2020-01|     631|          1804|         5970| 8405|
# |2020-02|     731|          1765|         5940| 8436|
# |2020-03|     699|          1983|         6270| 8952|
# |2020-04|     678|          1936|         6376| 8990|
# |2020-05|     444|          1978|         6709| 9131|
# |2020-06|     660|          2032|         6757| 9449|
# |2020-07|    1352|          2207|         7011|10570|
# |2020-08|    1034|          2294|         7530|10858|
# |2020-09|     809|          2187|         7626|10622|
# |2020-10|     839|          2320|         8010|11169|
# |2020-11|     874|          2403|         8193|11470|
# |2020-12|     463|          2393|         8628|11484|
# |2021-01|     868|          2690|         8713|12271|
# |2021-02|     786|          2393|         8575|11754|
# |2021-03|     867|          2842|         9203|12912|
# |2021-04|     758|          2748|         9284|12790|
# |2021-05|     468|          2886|         9936|13290|
# |2021-06|     770|          2745|         9767|13282|
# |2021-07|    1581|          3117|        10237|14935|
# |2021-08|    1163|          3013|        10819|14995|
# |2021-09|     973|          2858|        11333|15164|
# |2021-10|    1053|          3100|        11701|15854|
# |2021-11|    1007|          3118|        12066|16191|
# |2021-12|     473|          3105|        12682|16260|
# |2022-01|    1057|          3526|        12731|17314|
# |2022-02|     918|          2762|        12865|16545|
# |2022-03|     873|          3096|        13686|17655|
# |2022-04|     872|          3200|        13819|17891|
# |2022-05|     408|          2183|        14973|17564|
# |2022-06|     762|           369|        15188|16319|
# |2022-07|     998|            26|         8950| 9974|
# +-------+--------+--------------+-------------+-----+

# %%
mau_users_sdf.explain(mode="formatted")
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan (35)
# +- Project (34)
#    +- Project (33)
#       +- SortMergeJoin FullOuter (32)
#          :- Sort (22)
#          :  +- Exchange (21)
#          :     +- Project (20)
#          :        +- SortMergeJoin FullOuter (19)
#          :           :- Sort (9)
#          :           :  +- HashAggregate (8)
#          :           :     +- Exchange (7)
#          :           :        +- HashAggregate (6)
#          :           :           +- Project (5)
#          :           :              +- Filter (4)
#          :           :                 +- InMemoryTableScan (1)
#          :           :                       +- InMemoryRelation (2)
#          :           :                             +- * Scan JDBCRelation((
# SELECT CUST_ID
#      , DATE(YM01)                                                                          AS ORDR_YM_01
#      , DATE_FORMAT(YM01, '%Y-%m')                                                          AS ORDR_YM
#      , LAG(YM01, 1) OVER (PARTITION BY CUST_ID ORDER BY YM01)                              AS PRIOR_ORDR_YM
#      , TIMESTAMPDIFF(MONTH, LAG(YM01, 1) OVER (PARTITION BY CUST_ID ORDER BY YM01), YM01)  AS ORDR_MONTH_DIFF
# FROM (
#     SELECT DISTINCT CUST_ID
#                   , DATE_FORMAT(ORDR_DE, '%Y-%m-01') AS YM01
#       FROM dm.dm_f_ordr
#      WHERE ORDR_DE BETWEEN '1970-01-01' AND '2022-07-31'
#     ) AS user_monthly_order
# ) as subquery) [numPartitions=3]  (3)
#          :           +- Sort (18)
#          :              +- HashAggregate (17)
#          :                 +- Exchange (16)
#          :                    +- HashAggregate (15)
#          :                       +- Project (14)
#          :                          +- Filter (13)
#          :                             +- InMemoryTableScan (10)
#          :                                   +- InMemoryRelation (11)
#          :                                         +- * Scan JDBCRelation((
# SELECT CUST_ID
#      , DATE(YM01)                                                                          AS ORDR_YM_01
#      , DATE_FORMAT(YM01, '%Y-%m')                                                          AS ORDR_YM
#      , LAG(YM01, 1) OVER (PARTITION BY CUST_ID ORDER BY YM01)                              AS PRIOR_ORDR_YM
#      , TIMESTAMPDIFF(MONTH, LAG(YM01, 1) OVER (PARTITION BY CUST_ID ORDER BY YM01), YM01)  AS ORDR_MONTH_DIFF
# FROM (
#     SELECT DISTINCT CUST_ID
#                   , DATE_FORMAT(ORDR_DE, '%Y-%m-01') AS YM01
#       FROM dm.dm_f_ordr
#      WHERE ORDR_DE BETWEEN '1970-01-01' AND '2022-07-31'
#     ) AS user_monthly_order
# ) as subquery) [numPartitions=3]  (12)
#          +- Sort (31)
#             +- HashAggregate (30)
#                +- Exchange (29)
#                   +- HashAggregate (28)
#                      +- Project (27)
#                         +- Filter (26)
#                            +- InMemoryTableScan (23)
#                                  +- InMemoryRelation (24)
#                                        +- * Scan JDBCRelation((
# SELECT CUST_ID
#      , DATE(YM01)                                                                          AS ORDR_YM_01
#      , DATE_FORMAT(YM01, '%Y-%m')                                                          AS ORDR_YM
#      , LAG(YM01, 1) OVER (PARTITION BY CUST_ID ORDER BY YM01)                              AS PRIOR_ORDR_YM
#      , TIMESTAMPDIFF(MONTH, LAG(YM01, 1) OVER (PARTITION BY CUST_ID ORDER BY YM01), YM01)  AS ORDR_MONTH_DIFF
# FROM (
#     SELECT DISTINCT CUST_ID
#                   , DATE_FORMAT(ORDR_DE, '%Y-%m-01') AS YM01
#       FROM dm.dm_f_ordr
#      WHERE ORDR_DE BETWEEN '1970-01-01' AND '2022-07-31'
#     ) AS user_monthly_order
# ) as subquery) [numPartitions=3]  (25)
#
#
# (1) InMemoryTableScan
# Output [2]: [ORDR_MONTH_DIFF#6L, ORDR_YM#4]
# Arguments: [ORDR_MONTH_DIFF#6L, ORDR_YM#4], [isnull(ORDR_MONTH_DIFF#6L)]
#
# (2) InMemoryRelation
# Arguments: [CUST_ID#2, ORDR_YM_01#3, ORDR_YM#4, PRIOR_ORDR_YM#5, ORDR_MONTH_DIFF#6L], CachedRDDBuilder(org.apache.spark.sql.execution.columnar.DefaultCachedBatchSerializer@7e949b0f,StorageLevel(disk, memory, deserialized, 1 replicas),*(1) Scan JDBCRelation((
# SELECT CUST_ID
#      , DATE(YM01)                                                                          AS ORDR_YM_01
#      , DATE_FORMAT(YM01, '%Y-%m')                                                          AS ORDR_YM
#      , LAG(YM01, 1) OVER (PARTITION BY CUST_ID ORDER BY YM01)                              AS PRIOR_ORDR_YM
#      , TIMESTAMPDIFF(MONTH, LAG(YM01, 1) OVER (PARTITION BY CUST_ID ORDER BY YM01), YM01)  AS ORDR_MONTH_DIFF
# FROM (
#     SELECT DISTINCT CUST_ID
#                   , DATE_FORMAT(ORDR_DE, '%Y-%m-01') AS YM01
#       FROM dm.dm_f_ordr
#      WHERE ORDR_DE BETWEEN '1970-01-01' AND '2022-07-31'
#     ) AS user_monthly_order
# ) as subquery) [numPartitions=3] [CUST_ID#2,ORDR_YM_01#3,ORDR_YM#4,PRIOR_ORDR_YM#5,ORDR_MONTH_DIFF#6L] PushedFilters: [], ReadSchema: struct<CUST_ID:int,ORDR_YM_01:date,ORDR_YM:string,PRIOR_ORDR_YM:string,ORDR_MONTH_DIFF:bigint>
# ,None)
#
# (3) Scan JDBCRelation((
# SELECT CUST_ID
#      , DATE(YM01)                                                                          AS ORDR_YM_01
#      , DATE_FORMAT(YM01, '%Y-%m')                                                          AS ORDR_YM
#      , LAG(YM01, 1) OVER (PARTITION BY CUST_ID ORDER BY YM01)                              AS PRIOR_ORDR_YM
#      , TIMESTAMPDIFF(MONTH, LAG(YM01, 1) OVER (PARTITION BY CUST_ID ORDER BY YM01), YM01)  AS ORDR_MONTH_DIFF
# FROM (
#     SELECT DISTINCT CUST_ID
#                   , DATE_FORMAT(ORDR_DE, '%Y-%m-01') AS YM01
#       FROM dm.dm_f_ordr
#      WHERE ORDR_DE BETWEEN '1970-01-01' AND '2022-07-31'
#     ) AS user_monthly_order
# ) as subquery) [numPartitions=3]  [codegen id : 1]
# Output [5]: [CUST_ID#2, ORDR_YM_01#3, ORDR_YM#4, PRIOR_ORDR_YM#5, ORDR_MONTH_DIFF#6L]
# ReadSchema: struct<CUST_ID:int,ORDR_YM_01:date,ORDR_YM:string,PRIOR_ORDR_YM:string,ORDR_MONTH_DIFF:bigint>
#
# (4) Filter
# Input [2]: [ORDR_MONTH_DIFF#6L, ORDR_YM#4]
# Condition : isnull(ORDR_MONTH_DIFF#6L)
#
# (5) Project
# Output [1]: [ORDR_YM#4]
# Input [2]: [ORDR_MONTH_DIFF#6L, ORDR_YM#4]
#
# (6) HashAggregate
# Input [1]: [ORDR_YM#4]
# Keys [1]: [ORDR_YM#4]
# Functions [1]: [partial_count(ORDR_YM#4)]
# Aggregate Attributes [1]: [count#440L]
# Results [2]: [ORDR_YM#4, count#441L]
#
# (7) Exchange
# Input [2]: [ORDR_YM#4, count#441L]
# Arguments: hashpartitioning(ORDR_YM#4, 200), ENSURE_REQUIREMENTS, [plan_id=656]
#
# (8) HashAggregate
# Input [2]: [ORDR_YM#4, count#441L]
# Keys [1]: [ORDR_YM#4]
# Functions [1]: [count(ORDR_YM#4)]
# Aggregate Attributes [1]: [count(ORDR_YM#4)#142L]
# Results [2]: [ORDR_YM#4, count(ORDR_YM#4)#142L AS new_user#143L]
#
# (9) Sort
# Input [2]: [ORDR_YM#4, new_user#143L]
# Arguments: [ORDR_YM#4 ASC NULLS FIRST], false, 0
#
# (10) InMemoryTableScan
# Output [2]: [ORDR_MONTH_DIFF#168L, ORDR_YM#166]
# Arguments: [ORDR_MONTH_DIFF#168L, ORDR_YM#166], [isnotnull(ORDR_MONTH_DIFF#168L), (ORDR_MONTH_DIFF#168L >= 3)]
#
# (11) InMemoryRelation
# Arguments: [CUST_ID#164, ORDR_YM_01#165, ORDR_YM#166, PRIOR_ORDR_YM#167, ORDR_MONTH_DIFF#168L], CachedRDDBuilder(org.apache.spark.sql.execution.columnar.DefaultCachedBatchSerializer@7e949b0f,StorageLevel(disk, memory, deserialized, 1 replicas),*(1) Scan JDBCRelation((
# SELECT CUST_ID
#      , DATE(YM01)                                                                          AS ORDR_YM_01
#      , DATE_FORMAT(YM01, '%Y-%m')                                                          AS ORDR_YM
#      , LAG(YM01, 1) OVER (PARTITION BY CUST_ID ORDER BY YM01)                              AS PRIOR_ORDR_YM
#      , TIMESTAMPDIFF(MONTH, LAG(YM01, 1) OVER (PARTITION BY CUST_ID ORDER BY YM01), YM01)  AS ORDR_MONTH_DIFF
# FROM (
#     SELECT DISTINCT CUST_ID
#                   , DATE_FORMAT(ORDR_DE, '%Y-%m-01') AS YM01
#       FROM dm.dm_f_ordr
#      WHERE ORDR_DE BETWEEN '1970-01-01' AND '2022-07-31'
#     ) AS user_monthly_order
# ) as subquery) [numPartitions=3] [CUST_ID#2,ORDR_YM_01#3,ORDR_YM#4,PRIOR_ORDR_YM#5,ORDR_MONTH_DIFF#6L] PushedFilters: [], ReadSchema: struct<CUST_ID:int,ORDR_YM_01:date,ORDR_YM:string,PRIOR_ORDR_YM:string,ORDR_MONTH_DIFF:bigint>
# ,None)
#
# (12) Scan JDBCRelation((
# SELECT CUST_ID
#      , DATE(YM01)                                                                          AS ORDR_YM_01
#      , DATE_FORMAT(YM01, '%Y-%m')                                                          AS ORDR_YM
#      , LAG(YM01, 1) OVER (PARTITION BY CUST_ID ORDER BY YM01)                              AS PRIOR_ORDR_YM
#      , TIMESTAMPDIFF(MONTH, LAG(YM01, 1) OVER (PARTITION BY CUST_ID ORDER BY YM01), YM01)  AS ORDR_MONTH_DIFF
# FROM (
#     SELECT DISTINCT CUST_ID
#                   , DATE_FORMAT(ORDR_DE, '%Y-%m-01') AS YM01
#       FROM dm.dm_f_ordr
#      WHERE ORDR_DE BETWEEN '1970-01-01' AND '2022-07-31'
#     ) AS user_monthly_order
# ) as subquery) [numPartitions=3]  [codegen id : 1]
# Output [5]: [CUST_ID#2, ORDR_YM_01#3, ORDR_YM#4, PRIOR_ORDR_YM#5, ORDR_MONTH_DIFF#6L]
# ReadSchema: struct<CUST_ID:int,ORDR_YM_01:date,ORDR_YM:string,PRIOR_ORDR_YM:string,ORDR_MONTH_DIFF:bigint>
#
# (13) Filter
# Input [2]: [ORDR_MONTH_DIFF#168L, ORDR_YM#166]
# Condition : (isnotnull(ORDR_MONTH_DIFF#168L) AND (ORDR_MONTH_DIFF#168L >= 3))
#
# (14) Project
# Output [1]: [ORDR_YM#166]
# Input [2]: [ORDR_MONTH_DIFF#168L, ORDR_YM#166]
#
# (15) HashAggregate
# Input [1]: [ORDR_YM#166]
# Keys [1]: [ORDR_YM#166]
# Functions [1]: [partial_count(ORDR_YM#166)]
# Aggregate Attributes [1]: [count#442L]
# Results [2]: [ORDR_YM#166, count#443L]
#
# (16) Exchange
# Input [2]: [ORDR_YM#166, count#443L]
# Arguments: hashpartitioning(ORDR_YM#166, 200), ENSURE_REQUIREMENTS, [plan_id=658]
#
# (17) HashAggregate
# Input [2]: [ORDR_YM#166, count#443L]
# Keys [1]: [ORDR_YM#166]
# Functions [1]: [count(ORDR_YM#166)]
# Aggregate Attributes [1]: [count(ORDR_YM#166)#151L]
# Results [2]: [ORDR_YM#166, count(ORDR_YM#166)#151L AS returning_user#152L]
#
# (18) Sort
# Input [2]: [ORDR_YM#166, returning_user#152L]
# Arguments: [ORDR_YM#166 ASC NULLS FIRST], false, 0
#
# (19) SortMergeJoin
# Left keys [1]: [ORDR_YM#4]
# Right keys [1]: [ORDR_YM#166]
# Join type: FullOuter
# Join condition: None
#
# (20) Project
# Output [3]: [coalesce(ORDR_YM#4, ORDR_YM#166) AS ORDR_YM#169, new_user#143L, returning_user#152L]
# Input [4]: [ORDR_YM#4, new_user#143L, ORDR_YM#166, returning_user#152L]
#
# (21) Exchange
# Input [3]: [ORDR_YM#169, new_user#143L, returning_user#152L]
# Arguments: hashpartitioning(ORDR_YM#169, 200), ENSURE_REQUIREMENTS, [plan_id=670]
#
# (22) Sort
# Input [3]: [ORDR_YM#169, new_user#143L, returning_user#152L]
# Arguments: [ORDR_YM#169 ASC NULLS FIRST], false, 0
#
# (23) InMemoryTableScan
# Output [2]: [ORDR_MONTH_DIFF#177L, ORDR_YM#175]
# Arguments: [ORDR_MONTH_DIFF#177L, ORDR_YM#175], [isnotnull(ORDR_MONTH_DIFF#177L), (ORDR_MONTH_DIFF#177L <= 2)]
#
# (24) InMemoryRelation
# Arguments: [CUST_ID#173, ORDR_YM_01#174, ORDR_YM#175, PRIOR_ORDR_YM#176, ORDR_MONTH_DIFF#177L], CachedRDDBuilder(org.apache.spark.sql.execution.columnar.DefaultCachedBatchSerializer@7e949b0f,StorageLevel(disk, memory, deserialized, 1 replicas),*(1) Scan JDBCRelation((
# SELECT CUST_ID
#      , DATE(YM01)                                                                          AS ORDR_YM_01
#      , DATE_FORMAT(YM01, '%Y-%m')                                                          AS ORDR_YM
#      , LAG(YM01, 1) OVER (PARTITION BY CUST_ID ORDER BY YM01)                              AS PRIOR_ORDR_YM
#      , TIMESTAMPDIFF(MONTH, LAG(YM01, 1) OVER (PARTITION BY CUST_ID ORDER BY YM01), YM01)  AS ORDR_MONTH_DIFF
# FROM (
#     SELECT DISTINCT CUST_ID
#                   , DATE_FORMAT(ORDR_DE, '%Y-%m-01') AS YM01
#       FROM dm.dm_f_ordr
#      WHERE ORDR_DE BETWEEN '1970-01-01' AND '2022-07-31'
#     ) AS user_monthly_order
# ) as subquery) [numPartitions=3] [CUST_ID#2,ORDR_YM_01#3,ORDR_YM#4,PRIOR_ORDR_YM#5,ORDR_MONTH_DIFF#6L] PushedFilters: [], ReadSchema: struct<CUST_ID:int,ORDR_YM_01:date,ORDR_YM:string,PRIOR_ORDR_YM:string,ORDR_MONTH_DIFF:bigint>
# ,None)
#
# (25) Scan JDBCRelation((
# SELECT CUST_ID
#      , DATE(YM01)                                                                          AS ORDR_YM_01
#      , DATE_FORMAT(YM01, '%Y-%m')                                                          AS ORDR_YM
#      , LAG(YM01, 1) OVER (PARTITION BY CUST_ID ORDER BY YM01)                              AS PRIOR_ORDR_YM
#      , TIMESTAMPDIFF(MONTH, LAG(YM01, 1) OVER (PARTITION BY CUST_ID ORDER BY YM01), YM01)  AS ORDR_MONTH_DIFF
# FROM (
#     SELECT DISTINCT CUST_ID
#                   , DATE_FORMAT(ORDR_DE, '%Y-%m-01') AS YM01
#       FROM dm.dm_f_ordr
#      WHERE ORDR_DE BETWEEN '1970-01-01' AND '2022-07-31'
#     ) AS user_monthly_order
# ) as subquery) [numPartitions=3]  [codegen id : 1]
# Output [5]: [CUST_ID#2, ORDR_YM_01#3, ORDR_YM#4, PRIOR_ORDR_YM#5, ORDR_MONTH_DIFF#6L]
# ReadSchema: struct<CUST_ID:int,ORDR_YM_01:date,ORDR_YM:string,PRIOR_ORDR_YM:string,ORDR_MONTH_DIFF:bigint>
#
# (26) Filter
# Input [2]: [ORDR_MONTH_DIFF#177L, ORDR_YM#175]
# Condition : (isnotnull(ORDR_MONTH_DIFF#177L) AND (ORDR_MONTH_DIFF#177L <= 2))
#
# (27) Project
# Output [1]: [ORDR_YM#175]
# Input [2]: [ORDR_MONTH_DIFF#177L, ORDR_YM#175]
#
# (28) HashAggregate
# Input [1]: [ORDR_YM#175]
# Keys [1]: [ORDR_YM#175]
# Functions [1]: [partial_count(ORDR_YM#175)]
# Aggregate Attributes [1]: [count#444L]
# Results [2]: [ORDR_YM#175, count#445L]
#
# (29) Exchange
# Input [2]: [ORDR_YM#175, count#445L]
# Arguments: hashpartitioning(ORDR_YM#175, 200), ENSURE_REQUIREMENTS, [plan_id=666]
#
# (30) HashAggregate
# Input [2]: [ORDR_YM#175, count#445L]
# Keys [1]: [ORDR_YM#175]
# Functions [1]: [count(ORDR_YM#175)]
# Aggregate Attributes [1]: [count(ORDR_YM#175)#160L]
# Results [2]: [ORDR_YM#175, count(ORDR_YM#175)#160L AS existing_user#161L]
#
# (31) Sort
# Input [2]: [ORDR_YM#175, existing_user#161L]
# Arguments: [ORDR_YM#175 ASC NULLS FIRST], false, 0
#
# (32) SortMergeJoin
# Left keys [1]: [ORDR_YM#169]
# Right keys [1]: [ORDR_YM#175]
# Join type: FullOuter
# Join condition: None
#
# (33) Project
# Output [4]: [coalesce(ORDR_YM#169, ORDR_YM#175) AS ORDR_YM#178, coalesce(new_user#143L, 0) AS new_user#187L, coalesce(returning_user#152L, 0) AS returning_user#188L, coalesce(existing_user#161L, 0) AS existing_user#189L]
# Input [5]: [ORDR_YM#169, new_user#143L, returning_user#152L, ORDR_YM#175, existing_user#161L]
#
# (34) Project
# Output [5]: [ORDR_YM#178, new_user#187L, returning_user#188L, existing_user#189L, ((new_user#187L + returning_user#188L) + existing_user#189L) AS mau#194L]
# Input [4]: [ORDR_YM#178, new_user#187L, returning_user#188L, existing_user#189L]
#
# (35) AdaptiveSparkPlan
# Output [5]: [ORDR_YM#178, new_user#187L, returning_user#188L, existing_user#189L, mau#194L]
# Arguments: isFinalPlan=false

# %% [markdown]
# # Data Sinks

# %%
# Saving data to a JDBC source
mau_users_sdf.repartition(4).write \
    .format("jdbc") \
    .options(**DB_CONN_INFO) \
    .option("dbtable", "dw.snap_user_movenet") \
    .mode("overwrite") \
    .save()

# %% [markdown]
# # Stop SparkSession

# %%
spark.stop()
